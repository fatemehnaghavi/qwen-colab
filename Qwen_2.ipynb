# %% [markdown]
# <a href="https://colab.research.google.com/github/fatemehnaghavi/qwen-colab/blob/main/Qwen_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers accelerate torch

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Qwen/Qwen2-0.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

prompt = "Explain what artificial intelligence is in simple terms."

inputs = tokenizer(prompt, return_tensors="pt")

outputs = model.generate(**inputs, max_new_tokens=100)

print(tokenizer.decode(outputs[0]))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# ...

# %%
prompts = [
    "Explain artificial intelligence in simple words.",
    "Write a short motivational quote for students.",
    "What are three benefits of learning programming?"
]

for prompt in prompts:
    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_new_tokens=80)
    answer = tokenizer.decode(outputs[0])

    print("PROMPT:", prompt)
    print("RESPONSE:", answer)
    print("\n----------------\n")
# Out:
# PROMPT: Explain artificial intelligence in simple words.
# RESPONSE: Explain artificial intelligence in simple words. Artificial intelligence (AI) is a type of technology that uses algorithms to make machines learn and improve their own performance over time. It can do things like recognize patterns, understand natural language, play games, and even write code for computer programs. AI systems are designed to help humans perform tasks that would be too difficult or dangerous for humans to complete on their own, such as driving cars, playing sports,
#
# ----------------
#
# PROMPT: Write a short motivational quote for students.
# RESPONSE: Write a short motivational quote for students. "Success is not final, failure is not fatal: it is the courage to continue that counts." - Winston Churchill
#
# ...
